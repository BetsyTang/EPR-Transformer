# %%
from cus_tokenizers.expression import *

# %%
"""
Expression tokenizer.

* 0: Pitch;
* 1: Performance Velocity; -> PVelocity
* 2: Performance Duration; -> PDuration
* 3: Performance Inter Onset Interval (Onset time difference between the current note and the previous note); -> PIOI
* 4: Perfromance Position; -> PPosition
* 5: Perfromance Bar; -> PBar
* 6: Score Duration; -> SDuration
* 7: Score Inter Onset Interval; -> SIOI
* 8: Score Position; -> SPosition
* 9: Score Bar; -> SBar
* 10: Duration Deviation; -> SPDurationDev

**Notes:**
* Tokens are first sorted by time, then track, then pitch values.

"""

DATA_FOLDER = "/home/smg/v-jtbetsy/DATA/ATEPP-s2a"
align_path = "Ludwig_van_Beethoven/Piano_Sonata_No._7_in_D_Major,_Op._10_No._3/III._Menuetto._Allegro/05813_infer_corresp.txt"
performance_midi_path = "Ludwig_van_Beethoven/Piano_Sonata_No._7_in_D_Major,_Op._10_No._3/III._Menuetto._Allegro/05813.mid"
score_midi_path = "Ludwig_van_Beethoven/Piano_Sonata_No._7_in_D_Major,_Op._10_No._3/III._Menuetto._Allegro/musicxml_cleaned.musicxml.midi"

TOKENIZER_PARAMS = {
    "pitch_range": (21, 109),
    "beat_res": {(0, 12):TICKS_PER_BEAT},
    "num_velocities": 64,
    "special_tokens": ["PAD", "BOS", "EOS", "MASK"],
    "use_chords": False,
    "use_rests": False,
    "use_tempos": False,
    "use_time_signatures": False,
    "use_programs": False,
    "num_tempos": 32,  # number of tempo bins
    "tempo_range": (40, 250),  # (min, max)
    "data_type": "Alignment"
}


config = TokenizerConfig(**TOKENIZER_PARAMS)

tokenizer = ExpressionTok(
    config
)

performance_midi = Score(os.path.join(DATA_FOLDER, performance_midi_path))
tokens = tokenizer.alignment_to_token(os.path.join(DATA_FOLDER, align_path), performance_midi)
# print(tokenizer.vocab[3])
print(tokens[0])
# Out:
# 0
# [52, 23, 1023, 1540, 205, 4, 771, 1540, 4, 4, 2824]

# %%
tokenizer.token_id_type(2824, 10)
# Out:
# 'SPDurationDev'

# %%
print(list(tokenizer.vocab[10].keys())[list(tokenizer.vocab[10].values()).index(2824)])
# Out:
# SPDurationDev_252

# %%
print(tokenizer.vocab[10])
# Out:
# {'PAD_None': 0, 'BOS_None': 1, 'EOS_None': 2, 'MASK_None': 3, 'SPDurationDev_3072': 4, 'SPDurationDev_3071': 5, 'SPDurationDev_3070': 6, 'SPDurationDev_3069': 7, 'SPDurationDev_3068': 8, 'SPDurationDev_3067': 9, 'SPDurationDev_3066': 10, 'SPDurationDev_3065': 11, 'SPDurationDev_3064': 12, 'SPDurationDev_3063': 13, 'SPDurationDev_3062': 14, 'SPDurationDev_3061': 15, 'SPDurationDev_3060': 16, 'SPDurationDev_3059': 17, 'SPDurationDev_3058': 18, 'SPDurationDev_3057': 19, 'SPDurationDev_3056': 20, 'SPDurationDev_3055': 21, 'SPDurationDev_3054': 22, 'SPDurationDev_3053': 23, 'SPDurationDev_3052': 24, 'SPDurationDev_3051': 25, 'SPDurationDev_3050': 26, 'SPDurationDev_3049': 27, 'SPDurationDev_3048': 28, 'SPDurationDev_3047': 29, 'SPDurationDev_3046': 30, 'SPDurationDev_3045': 31, 'SPDurationDev_3044': 32, 'SPDurationDev_3043': 33, 'SPDurationDev_3042': 34, 'SPDurationDev_3041': 35, 'SPDurationDev_3040': 36, 'SPDurationDev_3039': 37, 'SPDurationDev_3038': 38, 'SPDurationDev_3037': 39, 'SPDurationDev_3036': 40, 'SPDurationDev_3035': 41, 'SPDurationDev_3034': 42, 'SPDurationDev_3033': 43, 'SPDurationDev_3032': 44, 'SPDurationDev_3031': 45, 'SPDurationDev_3030': 46, 'SPDurationDev_3029': 47, 'SPDurationDev_3028': 48, 'SPDurationDev_3027': 49, 'SPDurationDev_3026': 50, 'SPDurationDev_3025': 51, 'SPDurationDev_3024': 52, 'SPDurationDev_3023': 53, 'SPDurationDev_3022': 54, 'SPDurationDev_3021': 55, 'SPDurationDev_3020': 56, 'SPDurationDev_3019': 57, 'SPDurationDev_3018': 58, 'SPDurationDev_3017': 59, 'SPDurationDev_3016': 60, 'SPDurationDev_3015': 61, 'SPDurationDev_3014': 62, 'SPDurationDev_3013': 63, 'SPDurationDev_3012': 64, 'SPDurationDev_3011': 65, 'SPDurationDev_3010': 66, 'SPDurationDev_3009': 67, 'SPDurationDev_3008': 68, 'SPDurationDev_3007': 69, 'SPDurationDev_3006': 70, 'SPDurationDev_3005': 71, 'SPDurationDev_3004': 72, 'SPDurationDev_3003': 73, 'SPDurationDev_3002': 74, 'SPDurationDev_3001': 75, 'SPDurationDev_3000': 76, 'SPDurationDev_2999': 77, 'SPDurationDev_2998': 78, 'SPDurationDev_2997': 79, 'SPDurationDev_2996': 80, 'SPDurationDev_2995': 81, 'SPDurationDev_2994': 82, 'SPDurationDev_2993': 83, 'SPDurationDev_2992': 84, 'SPDurationDev_2991': 85, 'SPDurationDev_2990': 86, 'SPDurationDev_2989': 87, 'SPDurationDev_2988': 88, 'SPDurationDev_2987': 89, 'SPDurationDev_2986': 90, 'SPDurationDev_2985': 91, 'SPDurationDev_2984': 92, 'SPDurationDev_2983': 93, 'SPDurationDev_2982': 94, 'SPDurationDev_2981': 95, 'SPDurationDev_2980': 96, 'SPDurationDev_2979': 97, 'SPDurationDev_2978': 98, 'SPDurationDev_2977': 99, 'SPDurationDev_2976': 100, 'SPDurationDev_2975': 101, 'SPDurationDev_2974': 102, 'SPDurationDev_2973': 103, 'SPDurationDev_2972': 104, 'SPDurationDev_2971': 105, 'SPDurationDev_2970': 106, 'SPDurationDev_2969': 107, 'SPDurationDev_2968': 108, 'SPDurationDev_2967': 109, 'SPDurationDev_2966': 110, 'SPDurationDev_2965': 111, 'SPDurationDev_2964': 112, 'SPDurationDev_2963': 113, 'SPDurationDev_2962': 114, 'SPDurationDev_2961': 115, 'SPDurationDev_2960': 116, 'SPDurationDev_2959': 117, 'SPDurationDev_2958': 118, 'SPDurationDev_2957': 119, 'SPDurationDev_2956': 120, 'SPDurationDev_2955': 121, 'SPDurationDev_2954': 122, 'SPDurationDev_2953': 123, 'SPDurationDev_2952': 124, 'SPDurationDev_2951': 125, 'SPDurationDev_2950': 126, 'SPDurationDev_2949': 127, 'SPDurationDev_2948': 128, 'SPDurationDev_2947': 129, 'SPDurationDev_2946': 130, 'SPDurationDev_2945': 131, 'SPDurationDev_2944': 132, 'SPDurationDev_2943': 133, 'SPDurationDev_2942': 134, 'SPDurationDev_2941': 135, 'SPDurationDev_2940': 136, 'SPDurationDev_2939': 137, 'SPDurationDev_2938': 138, 'SPDurationDev_2937': 139, 'SPDurationDev_2936': 140, 'SPDurationDev_2935': 141, 'SPDurationDev_2934': 142, 'SPDurationDev_2933': 143, 'SPDurationDev_2932': 144, 'SPDurationDev_2931': 145, 'SPDurationDev_2930': 146, 'SPDurationDev_2929': 147, 'SPDurationDev_2928': 148, 'SPDurationDev_2927': 149, 'SPDurationDev_2926': 150, 'SPDurationDev_2925': 151, 'SPDurationDev_2924': 152, 'SPDurationDev_29 ...
